# %%
import pandas as pd
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor

# %%
dataset = pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0     False        True
# 1      18  33.770         1      True       False
# 2      28  33.000         3      True       False
# 3      33  22.705         0      True       False
# 4      32  28.880         0      True       False
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3      True       False
# 1334   18  31.920         0     False       False
# 1335   18  36.850         0     False       False
# 1336   21  25.800         0     False       False
# 1337   61  29.070         0     False        True
#
# [1338 rows x 5 columns]

# %%
dependent = dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
param_grid={
    "criterion": ["squared_error", "friedman_mse", "absolute_error", "poisson"],
    "splitter" : ["best","random"],
    "max_features": ["sqrt", "log2",None]
}
grid=GridSearchCV(DecisionTreeRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2', None],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re=grid.cv_results_
print("The R_Score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_Score value for best parameter {'criterion': 'squared_error', 'max_features': 'log2', 'splitter': 'best'}:

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.012998      0.001089         0.007220        0.001485
# 1        0.013848      0.004164         0.011180        0.002934
# 2        0.020318      0.003245         0.008623        0.001417
# 3        0.016396      0.002804         0.009673        0.002871
# 4        0.021337      0.002410         0.008157        0.000409
# 5        0.016639      0.002893         0.008460        0.001140
# 6        0.015316      0.002658         0.007270        0.000922
# 7        0.012233      0.002112         0.007337        0.001364
# 8        0.014073      0.002681         0.007557        0.000598
# 9        0.013262      0.002970         0.008933        0.003455
# 10       0.023696      0.009901         0.006593        0.001232
# 11       0.011355      0.002374         0.007816        0.002206
# 12       0.037737      0.006462         0.006513        0.002046
# 13       0.032336      0.005983         0.005911        0.001183
# 14       0.042332      0.003807         0.006769        0.001779
# 15       0.032214      0.005734         0.005986        0.001442
# 16       0.071568      0.008186         0.006146        0.001219
# 17       0.051336      0.004859         0.007593        0.001383
# 18       0.016079      0.002204         0.007457        0.001509
# 19       0.013941      0.000683         0.008174        0.001253
# 20       0.017669      0.001439         0.008126        0.000315
# 21       0.013808      0.001395         0.008754        0.000824
# 22       0.024821      0.001698         0.008871        0.001404
# 23       0.016338      0.001816         0.006687        0.000889
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4    squared_error               None           best
# 5    squared_error               None         random
# 6     friedman_mse               sqrt           best
# 7     friedman_mse               sqrt         random
# 8     friedman_mse               log2           best
# 9     friedman_mse               log2         random
# 10    friedman_mse               None           best
# 11    friedman_mse               None         random
# 12  absolute_error               sqrt           best
# 13  absolute_error               sqrt         random
# 14  absolute_error               log2           best
# 15  absolute_error               log2         random
# 16  absolute_error               None           best
# 17  absolute_error               None         random
# 18         poisson               sqrt           best
# 19         poisson               sqrt         random
# 20         poisson               log2           best
# 21         poisson               log2         random
# 22         poisson               None           best
# 23         poisson               None         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.683647
# 1   {'criterion': 'squared_error', 'max_features':...           0.682203
# 2   {'criterion': 'squared_error', 'max_features':...           0.747763
# 3   {'criterion': 'squared_error', 'max_features':...           0.683530
# 4   {'criterion': 'squared_error', 'max_features':...           0.718407
# 5   {'criterion': 'squared_error', 'max_features':...           0.718339
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.699496
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.578582
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.721285
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.641540
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.710510
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.681601
# 12  {'criterion': 'absolute_error', 'max_features'...           0.665444
# 13  {'criterion': 'absolute_error', 'max_features'...           0.709929
# 14  {'criterion': 'absolute_error', 'max_features'...           0.699361
# 15  {'criterion': 'absolute_error', 'max_features'...           0.740513
# 16  {'criterion': 'absolute_error', 'max_features'...           0.750504
# 17  {'criterion': 'absolute_error', 'max_features'...           0.643354
# 18  {'criterion': 'poisson', 'max_features': 'sqrt...           0.708519
# 19  {'criterion': 'poisson', 'max_features': 'sqrt...           0.740385
# 20  {'criterion': 'poisson', 'max_features': 'log2...           0.758952
# 21  {'criterion': 'poisson', 'max_features': 'log2...           0.695478
# 22  {'criterion': 'poisson', 'max_features': None,...           0.752369
# 23  {'criterion': 'poisson', 'max_features': None,...           0.724664
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.622710           0.774634           0.725590
# 1            0.491918           0.522156           0.711342
# 2            0.709497           0.748759           0.732051
# 3            0.449711           0.607768           0.736270
# 4            0.647404           0.726445           0.731345
# 5            0.597934           0.698992           0.654776
# 6            0.433030           0.681413           0.703446
# 7            0.528408           0.702063           0.628877
# 8            0.626324           0.749468           0.650816
# 9            0.530991           0.684090           0.665239
# 10           0.645239           0.734824           0.706037
# 11           0.598681           0.694349           0.672951
# 12           0.618298           0.743148           0.712729
# 13           0.578299           0.669678           0.637471
# 14           0.628083           0.740505           0.748156
# 15           0.583050           0.728091           0.643289
# 16           0.605838           0.720776           0.707660
# 17           0.659925           0.722269           0.671233
# 18           0.595401           0.746748           0.712902
# 19           0.505041           0.683369           0.706768
# 20           0.593268           0.658492           0.644295
# 21           0.621695           0.716461           0.738743
# 22           0.651462           0.755610           0.727891
# 23           0.619367           0.660457           0.763853
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.722295         0.705775        0.050590                3
# 1            0.674141         0.616352        0.090616               24
# 2            0.718466         0.731307        0.015598                1
# 3            0.627973         0.621050        0.096707               22
# 4            0.667751         0.698270        0.034094                7
# 5            0.718906         0.677789        0.046240               16
# 6            0.709747         0.645426        0.106615               20
# 7            0.646520         0.616890        0.059283               23
# 8            0.684690         0.686516        0.044884               14
# 9            0.616909         0.627754        0.053385               21
# 10           0.685753         0.696473        0.029997                8
# 11           0.736814         0.676879        0.044833               17
# 12           0.715412         0.691006        0.044105               11
# 13           0.747969         0.668669        0.058535               18
# 14           0.681180         0.699457        0.043554                6
# 15           0.751470         0.689283        0.065420               12
# 16           0.736105         0.704177        0.051232                5
# 17           0.758380         0.691032        0.042765               10
# 18           0.762438         0.705202        0.058529                4
# 19           0.655394         0.658192        0.081501               19
# 20           0.734324         0.677866        0.060699               15
# 21           0.661687         0.686813        0.041285               13
# 22           0.677367         0.712940        0.041579                2
# 23           0.713019         0.696272        0.050697                9

# %%
result=grid.predict([[38, 27, 2, True, False]])
result
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([6455.86265])

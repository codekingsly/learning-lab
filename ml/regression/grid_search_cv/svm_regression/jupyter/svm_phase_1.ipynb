# %%
import pandas as pd
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
import pickle

# %%
dataset = pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0     False        True
# 1      18  33.770         1      True       False
# 2      28  33.000         3      True       False
# 3      33  22.705         0      True       False
# 4      32  28.880         0      True       False
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3      True       False
# 1334   18  31.920         0     False       False
# 1335   18  36.850         0     False       False
# 1336   21  25.800         0     False       False
# 1337   61  29.070         0     False        True
#
# [1338 rows x 5 columns]

# %%
dependent = dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
param_grid={
    "C": [0.01, 0.1, 10, 100, 200, 500],
    "kernel": ["linear", "rbf", "poly", "sigmoid"]
}
grid=GridSearchCV(SVR(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [0.01, 0.1, 10, 100, 200, 500],
#                          'kernel': ['linear', 'rbf', 'poly', 'sigmoid']},
#              verbose=3)

# %%
re=grid.cv_results_
print("The R_Score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_Score value for best parameter {'C': 500, 'kernel': 'linear'}:

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.097251      0.002265         0.017082        0.000354     0.01
# 1        0.113744      0.004043         0.062329        0.002319     0.01
# 2        0.097270      0.002837         0.020216        0.003843     0.01
# 3        0.196815      0.028417         0.032418        0.006740     0.01
# 4        0.119343      0.020497         0.018518        0.002929     0.10
# 5        0.112290      0.003573         0.064345        0.003023     0.10
# 6        0.097860      0.002884         0.018397        0.000949     0.10
# 7        0.124978      0.002302         0.027201        0.000305     0.10
# 8        0.115875      0.009054         0.016685        0.000448    10.00
# 9        0.112815      0.003521         0.063009        0.001534    10.00
# 10       0.101940      0.004881         0.018567        0.000762    10.00
# 11       0.125974      0.001044         0.027004        0.001056    10.00
# 12       0.251415      0.009140         0.016918        0.001012   100.00
# 13       0.114679      0.004220         0.063714        0.002550   100.00
# 14       0.107346      0.002388         0.018530        0.000571   100.00
# 15       0.125069      0.002208         0.026082        0.000275   100.00
# 16       0.377367      0.146118         0.016249        0.000265   200.00
# 17       0.106322      0.001361         0.062783        0.002998   200.00
# 18       0.109211      0.002611         0.018515        0.000859   200.00
# 19       0.122735      0.001448         0.026342        0.000834   200.00
# 20       0.543979      0.056133         0.015674        0.001331   500.00
# 21       0.113219      0.003931         0.060174        0.001975   500.00
# 22       0.116964      0.005396         0.019069        0.002286   500.00
# 23       0.118849      0.007133         0.021047        0.003648   500.00
#
#    param_kernel                            params  split0_test_score  \
# 0        linear   {'C': 0.01, 'kernel': 'linear'}          -0.109285
# 1           rbf      {'C': 0.01, 'kernel': 'rbf'}          -0.115328
# 2          poly     {'C': 0.01, 'kernel': 'poly'}          -0.115293
# 3       sigmoid  {'C': 0.01, 'kernel': 'sigmoid'}          -0.115326
# 4        linear    {'C': 0.1, 'kernel': 'linear'}          -0.156586
# 5           rbf       {'C': 0.1, 'kernel': 'rbf'}          -0.115326
# 6          poly      {'C': 0.1, 'kernel': 'poly'}          -0.112857
# 7       sigmoid   {'C': 0.1, 'kernel': 'sigmoid'}          -0.115314
# 8        linear     {'C': 10, 'kernel': 'linear'}          -0.018943
# 9           rbf        {'C': 10, 'kernel': 'rbf'}          -0.110409
# 10         poly       {'C': 10, 'kernel': 'poly'}          -0.125153
# 11      sigmoid    {'C': 10, 'kernel': 'sigmoid'}          -0.116743
# 12       linear    {'C': 100, 'kernel': 'linear'}           0.559313
# 13          rbf       {'C': 100, 'kernel': 'rbf'}          -0.160182
# 14         poly      {'C': 100, 'kernel': 'poly'}          -0.132885
# 15      sigmoid   {'C': 100, 'kernel': 'sigmoid'}          -0.142455
# 16       linear    {'C': 200, 'kernel': 'linear'}           0.597540
# 17          rbf       {'C': 200, 'kernel': 'rbf'}          -0.164374
# 18         poly      {'C': 200, 'kernel': 'poly'}          -0.128637
# 19      sigmoid   {'C': 200, 'kernel': 'sigmoid'}          -0.199909
# 20       linear    {'C': 500, 'kernel': 'linear'}           0.632135
# 21          rbf       {'C': 500, 'kernel': 'rbf'}          -0.160916
# 22         poly      {'C': 500, 'kernel': 'poly'}          -0.111995
# 23      sigmoid   {'C': 500, 'kernel': 'sigmoid'}          -0.590878
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0           -0.090622          -0.073438          -0.097328
# 1           -0.113522          -0.081590          -0.106046
# 2           -0.112538          -0.081331          -0.106025
# 3           -0.113576          -0.081609          -0.106063
# 4           -0.102518          -0.117799          -0.140213
# 5           -0.113152          -0.081428          -0.105862
# 6           -0.105099          -0.077609          -0.104969
# 7           -0.113654          -0.081616          -0.106034
# 8            0.029886           0.022167           0.003112
# 9           -0.097459          -0.074488          -0.099597
# 10          -0.081505          -0.111907          -0.131602
# 11          -0.119312          -0.085214          -0.108210
# 12           0.521798           0.547691           0.538805
# 13          -0.107253          -0.123430          -0.137753
# 14          -0.082461          -0.129220          -0.139962
# 15          -0.160831          -0.117544          -0.137984
# 16           0.557538           0.586781           0.574764
# 17          -0.106426          -0.129065          -0.141841
# 18          -0.078468          -0.125003          -0.135484
# 19          -0.231836          -0.180189          -0.202001
# 20           0.587195           0.619095           0.610472
# 21          -0.103514          -0.128312          -0.139323
# 22          -0.061455          -0.105944          -0.118600
# 23          -0.759765          -0.609333          -0.619830
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.124690        -0.099073        0.017275                5
# 1           -0.107206        -0.104738        0.012107               10
# 2           -0.106953        -0.104428        0.012052                8
# 3           -0.107201        -0.104755        0.012108               11
# 4           -0.216269        -0.146677        0.039413               19
# 5           -0.107303        -0.104614        0.012116                9
# 6           -0.108333        -0.101773        0.012418                7
# 7           -0.107251        -0.104774        0.012116               12
# 8           -0.066653        -0.006086        0.034672                4
# 9           -0.124428        -0.101276        0.016459                6
# 10          -0.179328        -0.125899        0.031794               15
# 11          -0.108716        -0.107639        0.012029               13
# 12           0.508518         0.535225        0.018122                3
# 13          -0.209551        -0.147634        0.035511               20
# 14          -0.189219        -0.134749        0.033948               17
# 15          -0.130402        -0.137843        0.014263               18
# 16           0.555420         0.574409        0.016331                2
# 17          -0.216445        -0.151630        0.037448               22
# 18          -0.182919        -0.130102        0.033205               16
# 19          -0.180953        -0.198978        0.018802               23
# 20           0.589494         0.607678        0.017242                1
# 21          -0.213145        -0.149042        0.037006               21
# 22          -0.164165        -0.112432        0.032727               14
# 23          -0.539246        -0.623810        0.073409               24

# %%
result=grid.predict([[38, 27, 2, True, False]])
result
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# array([6846.15092953])
